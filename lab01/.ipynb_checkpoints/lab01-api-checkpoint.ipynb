# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
# 221329
# Alzheimer's Disease and Healthy Aging Data(https://healthdata.gov/dataset/Alzheimer-s-Disease-and-Healthy-Aging-Data/i2i7-abim)
# usar esse parametro ao abrir notebook: --NotebookApp.iopub_data_rate_limit=1.0e10

import io
import requests
import json
url = "https://chronicdata.cdc.gov/views/hfr9-rurv/rows.json?$limit=10&$offset=10"
js = requests.get(url).content
print(js.decode("utf-8"))

# %%
import io
import requests
import json
url = "https://data.gov.sg/api/action/datastore_search?resource_id=8dccb687-9265-415b-909a-86bcf578c22f&limit=10"
content = requests.get(url).content
unformatted_data = json.loads(content)
data = json.dumps(unformatted_data, indent=2)
print(data)
# Out:
# {
#   "help": "https://data.gov.sg/api/3/action/help_show?name=datastore_search",
#   "success": true,
#   "result": {
#     "resource_id": "8dccb687-9265-415b-909a-86bcf578c22f",
#     "fields": [
#       {
#         "type": "int4",
#         "id": "_id"
#       },
#       {
#         "type": "numeric",
#         "id": "year"
#       },
#       {
#         "type": "text",
#         "id": "age"
#       },
#       {
#         "type": "text",
#         "id": "media_activity"
#       },
#       {
#         "type": "numeric",
#         "id": "sample_size"
#       },
#       {
#         "type": "numeric",
#         "id": "ever_used"
#       }
#     ],
#     "records": [
#       {
#         "ever_used": "8.8",
#         "age": "15-19",
#         "sample_size": "161",
#         "year": "2013",
#         "_id": 1,
#         "media_activity": "Watch MediaCorp TV"
#       },
#       {
#         "ever_used": "0.7",
#         "age": "15-19",
#         "sample_size": "161",
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.

# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

url_tent = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_tent = requests.get(url_tent)
json_tent = data_tent.json()

print(json.dumps(json_tent, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
amado = json_tent["d"]["results"][0]["http://dbpedia.org/property/author"]["__deferred"]["uri"]
print("Autor da novela Tenda dos Milagres: " + amado)
# Out:
# Autor da novela Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()

uri_mesh = json_mi[0]["resource"]
bar = str.rindex(uri_mesh, "/")

url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()

json_terms = json_mid["terms"]

print("Termos para Aspirina:")

for term in json_terms:
    print(" - " + term["label"])
# Out:
# Termos para Aspirina:
#  - Aspirin
#  - 2-(Acetyloxy)benzoic Acid
#  - Acetylsalicylic Acid
#  - Acetysal
#  - Acylpyrin
#  - Aloxiprimum
#  - Colfarit
#  - Dispril
#  - Easprin
#  - Ecotrin
#  - Endosprin
#  - Magnecyl
#  - Micristin
#  - Polopirin
#  - Polopiryna
#  - Solprin
#  - Solupsan
#  - Zorprin

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Canadian War Museum"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))

print(museum_ref[0]["osm_id"])

url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))

print(museum_way["elements"][0]["tags"]["wikipedia"])

url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# [
#    {
#       "place_id": 112862190,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 103438401,
#       "boundingbox": [
#          "45.4164188",
#          "45.417752",
#          "-75.718591",
#          "-75.7154601"
#       ],
#       "lat": "45.417121699999996",
#       "lon": "-75.71663421984586",
#       "display_name": "Canadian War Museum, 1, Vimy Place, Lebreton Flats, Somerset, (Old) Ottawa, Ottawa, Eastern Ontario, Ontario, K1A 0M8, Canada",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.7004118308283028,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    }
# ]
# 103438401
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (3486328 spike-08.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 103438401,
#          "timestamp": "2019-11-01T20:23:03Z",
#          "version": 17,
#          "changeset": 76513150,
#          "user": "zzptichka",
#          "uid": 215433,
#          "nodes": [
#             475493729,
#             1194391810,
#             6355742528,
#             475493717,
#             1194391932,
#             5984563323,
#             5984563328,
#             1194392528,
#             1194392037,
#             475493715,
#             5984563327,
#             2380161736,
#             2904720675,
#             5984563324,
#             5984563325,
#             475493718,
#             1194391959,
#             5984563326,
#             475493730,
#             475493719,
#             1194392295,
#             1194392199,
#             475493720,
#             475493721,
#             5984563335,
#             475493722,
#             1194391928,
#             1194392471,
#             1194392118,
#             1194392296,
#             475493723,
#             475493724,
#             475493725,
#             1194392020,
#             475493726,
#             1194392343,
#             1194391971,
#             1194392469,
#             5984563322,
#             475493729
#          ],
#          "tags": {
#             "addr:housenumber": "1",
#             "addr:postcode": "K1A 0M8",
#             "addr:street": "Vimy Place",
#             "building": "yes",
#             "internet_access": "wlan",
#             "name": "Canadian War Museum",
#             "name:de": "Kanadisches Kriegsmuseum",
#             "name:en": "Canadian War Museum",
#             "name:fr": "Mus\u00e9e Canadian de la Guerre",
#             "name:ko": "\uce90\ub098\ub2e4 \uc804\uc7c1\ubc15\ubb3c\uad00",
#             "opening_hours": "May-Jun: Fr-We 09:00-17:00; Jul-Aug: Fr-We 09:00-18:00; May-Aug: Th 09:00-20:00; Sep-Apr: Fr-We 09:30-17:00; Sep-Apr: Th 09:30-20:00",
#             "phone": "+1-800-555-5621",
#             "tourism": "museum",
#             "website": "https://www.warmuseum.ca/",
#             "wheelchair": "yes",
#             "wikidata": "Q1032442",
#             "wikipedia": "en:Canadian War Museum"
#          }
#       }
#    ]
# }
# en:Canadian War Museum
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Canadian_War_Museum"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Andrew_McNaughton"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Ottawa_landmarks"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "Het Canada War Museum is een oorlogsmuseum in het Belgische dorp Adegem. Het museum heeft vooral aandacht voor de Canadese en Poolse soldaten die meehielpen het Meetjesland te bevrijden tijdens de Tweede Wereldoorlog. Het museum werd officieel geopend in 1995. Voor de ingang van het museum staat een M10 Wolverine op een sokkel.",
#             "http://dbpedia.org/property/logo": "Canadian_War_Museum_logo.svg",
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Het Canadian War Museum (CWM) is een openbaar toeristisch museum voor militaire geschiedenis, dat gelegen is in Ottawa, Canada. CWM is het nationale oorlogsmuseum van Canada. De exposities vari\u00ebren van oudere oorlogen zoals de Tweede Wereldoorlog tot de huidige oorlogen waar Canada bij betrokken is. Het museum is formeel geopend in 1942, hoewel delen van de collectie afkomstig zijn uit een militair museum dat van 1880 tot 1896 actief was. Tot 1967 was het museum onder beheer van de Publieke Archieven van Canada.",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Canadian War Museum",
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://www.friends-amis.org/index.php/en/"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Depository103177349"
#                }
#             },
#             "http://dbpedia.org/property/caption": "Exterior of the museum in 2007",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Canadian_Museum_of_History_Corporation"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://hy.dbpedia.org/resource/\u053f\u0561\u0576\u0561\u0564\u0561\u0575\u056b_\u057c\u0561\u0566\u0574\u0561\u056f\u0561\u0576_\u0569\u0561\u0576\u0563\u0561\u0580\u0561\u0576"
#                }
#             },
#             "http://dbpedia.org/property/owner": "Canadian Museum of History Corporation",
#             "http://dbpedia.org/property/name": "Canadian War Museum",
#             "http://dbpedia.org/property/image": "Gallery 1 Battleground.jpg",
#             "http://dbpedia.org/property/nativeName": "Mus\u00e9e canadien de la guerre",
#             "http://dbpedia.org/property/president": "Mark O&#39;Niell",
#             "http://dbpedia.org/ontology/wikiPageLength": "60268",
#             "http://dbpedia.org/property/website": {
#                "__deferred": {
#                   "uri": "https://www.warmuseum.ca"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Canadian_War_Museum_new_building_2007.jpg"
#                }
#             },
#             "http://dbpedia.org/property/width": "152",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Ontario"
#                }
#             },
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Canadian_War_Museum_new_building_2007.jpg?width=300"
#                }
#             },
#             "http://dbpedia.org/property/location": "1",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/141831848"
#                }
#             },
#             "http://dbpedia.org/property/chairperson": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/James_Fleck"
#                }
#             },
#             "http://dbpedia.org/property/network": "Canadian Museum of Civilization Corporation",
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Museum"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "https://www.warmuseum.ca"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Canadian_War_Museum"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1026112648",
#             "http://dbpedia.org/property/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Museum"
#                }
#             },
#             "http://www.georss.org/georss/point": "45.41722222222222 -75.71722222222222",
#             "http://dbpedia.org/property/director": "Caroline Dromaguet",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-75.71722412109375",
#             "http://dbpedia.org/property/nativeNameLang": "French",
#             "http://dbpedia.org/ontology/wikiPageID": "248038",
#             "http://dbpedia.org/property/publictransit": "Pimisi",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Canada"
#                }
#             },
#             "http://dbpedia.org/property/perrow": "2",
#             "http://dbpedia.org/property/align": "left",
#             "http://dbpedia.org/property/architect": "Moriyama &amp; Teshima Architects &amp; Griffiths Rankin Cook Architects",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-75.717224121094 45.417221069336)",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "45.41722106933594",
#             "http://xmlns.com/foaf/0.1/name": "Canadian War Museum",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Canadian_War_Museum?oldid=1026112648&ns=0"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
